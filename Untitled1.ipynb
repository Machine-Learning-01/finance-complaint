# %%
import pandas as pd

# %%
import os
data_dir="finance_artifact/data_ingestion/20220904_124817/downloaded_dir"
dfs = [] # an empty list to store the data frames
for file in os.listdir(data_dir):
    data = pd.read_json(os.path.join(data_dir,file)) # read data frame from json file
    dfs.append(data) # append the data frame to the list
    print(data.shape)

temp = pd.concat(dfs, ignore_index=True)
# Out:
# (128231, 18)
# (364067, 18)
# (100359, 18)
# (75436, 18)
# (191438, 18)
# (87325, 18)
# (254245, 18)
# (255345, 18)
# (244877, 18)
# (38290, 18)
# (56564, 18)
# (78508, 18)
# (51932, 18)
# (34155, 18)
# (92276, 18)
# (121553, 18)
# (115470, 18)
# (145063, 18)
# (133163, 18)
# (136272, 18)
# (82206, 18)

# %%
temp.head()
# Out:
#                                              product  \
# 0                                       Student loan
# 1                                    Debt collection
# 2  Credit reporting, credit repair services, or o...
# 3  Credit reporting, credit repair services, or o...
# 4                        Credit card or prepaid card
#
#                              complaint_what_happened  \
# 0  I took out my first private loan with XXXX XXX...
# 1
# 2  I sent EQUIFAX, written requested for full fil...
# 3  I mailed in a request for credit line blocking...
# 4  Capital One Bank has my current balance owed a...
#
#         date_sent_to_company  \
# 0  2017-07-05T12:00:00-05:00
# 1  2017-07-06T12:00:00-05:00
# 2  2017-07-04T12:00:00-05:00
# 3  2017-07-06T12:00:00-05:00
# 4  2017-07-06T12:00:00-05:00
#
#                                                issue  \
# 0                      Struggling to repay your loan
# 1                  Attempts to collect debt not owed
# ...

# %%
temp.columns
# Out:
# Index(['product', 'complaint_what_happened', 'date_sent_to_company', 'issue',
#        'sub_product', 'zip_code', 'tags', 'complaint_id', 'timely',
#        'consumer_consent_provided', 'company_response', 'submitted_via',
#        'company', 'date_received', 'state', 'consumer_disputed',
#        'company_public_response', 'sub_issue'],
#       dtype='object')

# %%
temp.to_parquet("company.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 temp.to_parquet("company.parquet")
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
#    2750 Write a DataFrame to the binary parquet format.
#    2751
#    (...)
#    2831 >>> content = f.read()
#    2832 """
#    2833 from pandas.io.parquet import to_parquet
# -> 2835 return to_parquet(
#    2836     self,
#    2837     path,
#    2838     engine,
# ...
